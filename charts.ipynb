# %%
# u(P) при разных T
# Рис.1

import numpy as np
import matplotlib.pyplot as plt

a0=0.00477762; a1=0.02952904; a2=0.00012817
b0=1; b1=0.0059004; b2=-0.00097392

fontsize=12

P = np.linspace(-105., 100.0, num=1000)
T1 = 103.15; T2 = 293.13; T3 = 373.15
m1 = (a0 + a1*P + a2*T1)/(1. + b1*P + b2*T1)
m2 = (a0 + a1*P + a2*T2)/(1. + b1*P + b2*T2)
m3 = (a0 + a1*P + a2*T3)/(1. + b1*P + b2*T3)
plt.gca().set(xlim=(-200., 100.), ylim=(-10., 10.))
plt.xlabel('P, атм', fontsize=fontsize, fontfamily=fontfamily)
plt.ylabel(r'$m(P, T_i), \frac{г}{см^{2}\cdot c}$', fontsize=fontsize, fontfamily="SimHei")
plt.grid(linestyle = '--')
plt.plot(P, m1, color='#1512a5') # 1я кривая
plt.plot(P, m2, color='#19a327') # 2я кривая
plt.plot(P, m3, color='#a3195c') # 3я кривая
plt.plot([-1000, 1000], [0,0], linewidth = 0.5, color='black') # горизонтальная ось
plt.plot([0,0], [-1000, 1000], linewidth = 0.5, color='black') # вертикальная ось
plt.plot([-152.4, -152.4], [1000,-1000], linestyle = '--', linewidth = 1, color='#1512a5') #1я верт.асимптота
plt.text(-165, -7.5, '$P(103.15)_{КЗТП}$', fontsize=fontsize, rotation=90) #надпись к 1й верт.асимптоте
plt.plot([-121.1, -121.1], [1000,-1000], linestyle = '--', linewidth = 1, color='#19a327') #2я верт.асимптота
plt.text(-133, -7.5, '$P(293.15)_{КЗТП}$', fontsize=fontsize, fontfamily=fontfamily, rotation=90) #надпись ко 2й верт.асимптоте
plt.plot([-108.9, -108.9], [1000,-1000], linestyle = '--', linewidth = 1, color='#a3195c') #3я верт.асимптота
plt.text(-107, -7.5, '$P(373.15)_{КЗТП}$', fontsize=fontsize, fontfamily=fontfamily, rotation=90) #надпись ко 3й верт.асимптоте
plt.plot([-1000, 1000], [5, 5], linestyle = '--', linewidth = 1, color='#1512a5') #гор.асимптота
plt.text(33, 5.3, '$a_P$', fontsize=12) #надпись к гор.асимптоте
plt.annotate("1", xy=(-70, -4.3), xytext=(-80, -1.5), arrowprops=dict(arrowstyle = "->", connectionstyle = "arc3"), fontfamily=fontfamily) # аннотация к 1й кривой
plt.annotate("2", xy=(-60, -4.3), xytext=(-30, -5.5), arrowprops=dict(arrowstyle = "->", connectionstyle = "arc3"), fontfamily=fontfamily) # аннотация ко 2й кривой
plt.annotate("3", xy=(-65, -7), xytext=(-30, -7.5), arrowprops=dict(arrowstyle = "->", connectionstyle = "arc3"), fontfamily=fontfamily) # аннотация к 3й кривой
plt.scatter(-4.5, -0.1316, color='black', s=15, marker='o')
plt.text(-10, -1.6, 'A', fontsize=fontsize, fontfamily="Times New Roman") # точка А
plt.savefig('Fig1.png', dpi=400, bbox_inches='tight')

# %%
# ν_зтв при разных T
# Рис.2

a0=0.00477762; a1=0.02952904; a2=0.00012817
b0=1; b1=0.0059004; b2=-0.00097392

T1 = 103.15; T2 = 293.13; T3 = 373.15
P1 = np.linspace(-20., -1.8, num=1000)
P2 = np.linspace(-0.6, 100.0, num=1000)
nu1 = a1*P1 /(a0 + a1*P1 + a2*T1); nu4 = a1*P2 /(a0 + a1*P2 + a2*T1);
nu2 = a1*P1 /(a0 + a1*P1 + a2*T2); nu5 = a1*P2 /(a0 + a1*P2 + a2*T2);
nu3 = a1*P1 /(a0 + a1*P1 + a2*T3); nu6 = a1*P2 /(a0 + a1*P2 + a2*T3);

plt.gca().set(xlim=(-20., 100.), ylim=(-0.5, 1.75))
plt.xlabel('P, атм', fontsize=12)
plt.ylabel(r'$\nu_P(P, T_i)_{ЗТВ}$', fontsize=12)
plt.grid(linestyle = '--')
plt.plot(P1, nu1, color='#1512a5'); plt.plot(P2, nu4, color='#1512a5') # 1я кривая
plt.plot(P1, nu2, color='#19a327'); plt.plot(P2, nu5, color='#19a327') # 2я кривая
plt.plot(P1, nu3, color='#a3195c'); plt.plot(P2, nu6, color='#a3195c') # 3я кривая
plt.plot([-0.6095, -0.6095], [1000,-1000], linestyle = '--', linewidth = 1, color='#1512a5') #1я верт.асимптота
plt.annotate('$P(103.15)_{КЗТП}$', xy=(-1.2, 1.05), xytext=(8, 1.4),
            arrowprops=dict(arrowstyle = "->", connectionstyle = "arc3")) # аннотация к 1й верт.асимптоте
plt.annotate('$P(293.15)_{КЗТП}$', xy=(-2.1, 0.85), xytext=(10, 0.55),
            arrowprops=dict(arrowstyle = "->", connectionstyle = "arc3")) # аннотация ко 2й верт.асимптоте
plt.text(-6.6, -0.11, '$P(373.15)_{КЗТП}$', fontsize=12, rotation=90) #надпись к 3й верт.асимптоте
plt.plot([-1.4341, -1.4341], [1000,-1000], linestyle = '--', linewidth = 1, color='#19a327') #2я верт.асимптота
plt.plot([-1.7814, -1.7814], [1000,-1000], linestyle = '--', linewidth = 1, color='#a3195c') #3я верт.асимптота

plt.plot([-1000, 1000], [1, 1], linestyle = '--', linewidth = 1, color='#1512a5') #гор.асимптота ap
plt.text(6.5, 1.035, '$a_P$', fontsize=12) #надпись к гор.асимптоте

plt.annotate('3', xy=(-13, 1.15), xytext=(-17.5, 1.35),
            arrowprops=dict(arrowstyle = "->", connectionstyle = "arc3")) # аннотация к 3й кривой
plt.annotate('2', xy=(-10, 1.135), xytext=(-13.5, 1.35),
            arrowprops=dict(arrowstyle = "->", connectionstyle = "arc3")) # аннотация ко 2й кривой
plt.annotate('1', xy=(-10, 1.08), xytext=(-13.5, 0.8),
            arrowprops=dict(arrowstyle = "->", connectionstyle = "arc3")) # аннотация к 1й кривой
plt.savefig('Fig2.png', dpi=400, bbox_inches='tight')

# %%
# ν_зтп при разных T
# Рис.3

a0=0.00477762; a1=0.02952904; a2=0.00012817
b0=1; b1=0.0059004; b2=-0.00097392

T1 = 103.15; T2 = 293.13; T3 = 373.15
P = np.linspace(-100., 50., num=1000)
nu1 = -b1*P /(b0 + b1*P + b2*T1); nu2 = -b1*P /(b0 + b1*P + b2*T2); nu3 = -b1*P /(b0 + b1*P + b2*T3);
plt.gca().set(xlim=(-200., 50.), ylim=(-1.5, 1.))
plt.xlabel('P, атм', fontsize=12)
plt.ylabel(r'$\nu_P(P, T_i)_{ЗТП}$', fontsize=12)
plt.grid(linestyle = '--')
plt.plot(P, nu1, color='#1512a5'); plt.plot(P, nu2, color='#19a327'); plt.plot(P, nu3, color='#a3195c')
plt.plot([-1000, 1000], [0,0], linewidth = 0.5, color='black') # горизонтальная ось
plt.plot([0,0], [-1000, 1000], linewidth = 0.5, color='black') # вертикальная ось
plt.plot([-152.4, -152.4], [1000,-1000], linestyle = '--', linewidth = 1, color='#1512a5') #1я верт.асимптота
plt.text(-163, -0.92, '$P(103.15)_{КЗТП}$', fontsize=10, rotation=90) #надпись к 1й верт.асимптоте
plt.plot([-121.1, -121.1], [1000,-1000], linestyle = '--', linewidth = 1, color='#19a327') #2я верт.асимптота
plt.text(-132, -0.92, '$P(293.15)_{КЗТП}$', fontsize=10, rotation=90) #надпись ко 2й верт.асимптоте
plt.plot([-108.9, -108.9], [1000,-1000], linestyle = '--', linewidth = 1, color='#a3195c') #3я верт.асимптота
plt.text(-107, -0.92, '$P(373.15)_{КЗТП}$', fontsize=10, rotation=90) #надпись ко 3й верт.асимптоте
plt.plot([-1000, 1000], [-1, -1], linestyle = '--', linewidth = 1, color='#1512a5') #гор.асимптота ap
plt.text(20, -0.96, '$a_P$', fontsize=12) #надпись к гор.асимптоте

plt.text(-68, 0.55, '1', fontsize=10) #надпись к 1й кривой
plt.text(-61, 0.7, '2', fontsize=10) #надпись ко 2й кривой
plt.text(-48, 0.86, '3', fontsize=10) #надпись к 3й кривой
plt.savefig('Fig3.png', dpi=400, bbox_inches='tight')

# %%
# ν_зтп + ν_зтв при разных T
# Рис.4

a0=0.00477762; a1=0.02952904; a2=0.00012817
b0=1; b1=0.0059004; b2=-0.00097392

T1 = 103.15; T2 = 293.13; T3 = 373.15
P = np.linspace(-0.6, 100., num=1000)
nu1 = a1*P /(a0 + a1*P + a2*T1) - b1*P /(b0 + b1*P + b2*T1)
nu2 = a1*P /(a0 + a1*P + a2*T2) - b1*P /(b0 + b1*P + b2*T2)
nu3 = a1*P /(a0 + a1*P + a2*T3) - b1*P /(b0 + b1*P + b2*T3)
plt.gca().set(xlim=(-20, 100), ylim=(-0.5, 1.))
plt.xlabel('P, атм', fontsize=12)
plt.ylabel(r'$\nu_P(P, T_i)$', fontsize=12)
plt.grid(linestyle = '--')
plt.plot(P, nu1, color='#1512a5'); plt.plot(P, nu2, color='#19a327'); plt.plot(P, nu3, color='#a3195c')
plt.plot([-1000, 1000], [0,0], linewidth = 0.5, color='black') # горизонтальная ось
plt.plot([0,0], [-1000, 1000], linewidth = 0.5, color='black') # вертикальная ось
plt.plot([-1000, 1000], [-0.001, -0.001], linestyle = '--', linewidth = 1, color='#1512a5') #гор.асимптота ap
plt.text(28, 0.02, '$a_P$', fontsize=12) #надпись к гор.асимптоте

#1я проекция на P
plt.plot([P[nu1.argmax()], P[nu1.argmax()]], [nu1.max(),0], linestyle = '--', linewidth = 1, color='#1512a5')
plt.plot([0, P[nu1.argmax()]], [nu1.max(), nu1.max()], linestyle = '--', linewidth = 1, color='#1512a5')

#2я проекция на P
plt.plot([P[nu2.argmax()], P[nu2.argmax()]], [nu2.max(),0], linestyle = '--', linewidth = 1, color='#19a327')
plt.plot([0, P[nu2.argmax()]], [nu2.max(), nu2.max()], linestyle = '--', linewidth = 1, color='#19a327')

#3я проекция на P
plt.plot([P[nu3.argmax()], P[nu3.argmax()]], [nu3.max(),0], linestyle = '--', linewidth = 1, color='#a3195c')
plt.plot([0, P[nu3.argmax()]], [nu3.max(), nu3.max()], linestyle = '--', linewidth = 1, color='#a3195c')

plt.text(14, 0.9, '1', fontsize=12) #надпись к 1й кривой
plt.text(10, 0.812, '2', fontsize=12) #надпись ко 2й кривой
plt.text(16, 0.7, '3', fontsize=12) #надпись к 3й кривой

plt.text(-19, 0.9, r'$\nu(103.15)_{max}$', fontsize=8) #надпись к 1й проекции на ν
plt.text(-19, 0.82, r'$\nu(293.15)_{max}$', fontsize=8) #надпись ко 2й проекции на ν
plt.text(-19, 0.74, r'$\nu(373.15)_{max}$', fontsize=8) #надпись ко 3й проекции на ν
plt.text(5.6, -0.43, r'$P(103.15)_{\nu_{max}}$', fontsize=10, rotation=90) #надпись к 1й проекции на P
plt.text(10.3, -0.43, r'$P(293.15)_{\nu_{max}}$', fontsize=10, rotation=90) #надпись к 2й проекции на P
plt.text(14.8, 0.052, r'$P(373.15)_{\nu_{max}}$', fontsize=10, rotation=90) #надпись к 3й проекции на P
plt.savefig('Fig4.png', dpi=400, bbox_inches='tight')

# %%
# m(T) при разных P
# Рис.5

a0=0.00477762; a1=0.02952904; a2=0.00012817
b0=1; b1=0.0059004; b2=-0.00097392

p1 = 1; p2 = 5; p3 = 10
T1 = np.linspace(-3000, 1032.8, num=1000); T2 = np.linspace(-3000, 1056., num=1000); T3 = np.linspace(-3000, 1086., num=1000)
T4 = np.linspace(1033., 2000, num=1000); T5 = np.linspace(1058, 2000, num=1000); T6 = np.linspace(1088, 2000, num=1000)
m1 = (a0 + a1*p1 + a2*T1)/(1 + b1*p1 + b2*T1); m4 = (a0 + a1*p1 + a2*T4)/(1 + b1*p1 + b2*T4)
m2 = (a0 + a1*p2 + a2*T2)/(1 + b1*p2 + b2*T2); m5 = (a0 + a1*p2 + a2*T5)/(1 + b1*p2 + b2*T5)
m3 = (a0 + a1*p3 + a2*T3)/(1 + b1*p3 + b2*T3); m6 = (a0 + a1*p3 + a2*T6)/(1 + b1*p3 + b2*T6)
plt.gca().set(xlim=(-3000, 2000), ylim=(-10, 10))
plt.xlabel('T, K', fontsize=12)
plt.ylabel(r'$m(T), \frac{г}{см^{2}\cdot c}$', fontsize=12)
plt.grid(linestyle = '--')
plt.plot(T1, m1, color='#1512a5'); plt.plot(T2, m2, color='#19a327'); plt.plot(T3, m3, color='#a3195c')
plt.plot(T4, m4, color='#1512a5'); plt.plot(T5, m5, color='#19a327'); plt.plot(T6, m6, color='#a3195c')
plt.plot([-2000, 2000], [0,0], linewidth = 0.5, color='black') # горизонтальная ось
plt.plot([0,0], [-2000, 2000], linewidth = 0.5, color='black') # вертикальная ось
plt.plot([1032.83628, 1032.83628], [1000,-1000], linestyle = '--', linewidth = 1, color='#1512a5') #1я верт.асимптота

plt.plot([1057.073, 1057.073], [1000,-1000], linestyle = '--', linewidth = 1, color='#19a327') #2я верт.асимптота

plt.plot([1087.36075, 1087.36075], [1000,-1000], linestyle = '--', linewidth = 1, color='#a3195c') #3я верт.асимптота

plt.scatter(999.39, 4.997, color='black', s=15, marker='o')
plt.text(825, 5.2, 'B', fontsize=12) # точка Б
plt.scatter(-267.66, 0, color='black', s=15, marker='o')
plt.text(-267.66-60., 0.6, 'C', fontsize=12) # точка С
plt.scatter(-1189.22, 0, color='black', s=15, marker='o')
plt.text(-1189.22-60., 0.6, 'D', fontsize=12) # точка Д
plt.scatter(-2341.17, 0, color='black', s=15, marker='o')
plt.text(-2341.17-60., 0.6, 'E', fontsize=12) # точка Д

plt.text(1120, -0.9, '1', fontsize=10) # кривая 1
plt.annotate('2', xy=(1170, -2), xytext=(1460, -3.6),
            arrowprops=dict(arrowstyle = "->", connectionstyle = "arc3")) # аннотация ко 2й кривой
plt.text(1600, -1.9, '3', fontsize=10) # кривая 3
plt.savefig('Fig5.png', dpi=400, bbox_inches='tight')

# %%
# β(P,T)_зтв при разных P
# Рис.6

a0=0.00477762; a1=0.02952904; a2=0.00012817
b0=1; b1=0.0059004; b2=-0.00097392

T1 = np.linspace(-3000, -268, num=1000); T2 = np.linspace(-3000, -1190, num=1000); T3 = np.linspace(-3000, -2342, num=1000)
T4 = np.linspace(-266, 1000, num=1000); T5 = np.linspace(-1188, 1000, num=1000); T6 = np.linspace(-2340, 1000, num=1000)
beta1 = 0.00012817/(0.00477762 + 0.02952904*1 + 0.00012817*T1); beta4 = 0.00012817/(0.00477762 + 0.02952904*1 + 0.00012817*T4)
beta2 = 0.00012817/(0.00477762 + 0.02952904*5 + 0.00012817*T2); beta5 = 0.00012817/(0.00477762 + 0.02952904*5 + 0.00012817*T5)
beta3 = 0.00012817/(0.00477762 + 0.02952904*10 + 0.00012817*T3); beta6 = 0.00012817/(0.00477762 + 0.02952904*10 + 0.00012817*T6)
plt.gca().set(xlim=(-3000, 1000), ylim=(-0.01, 0.01))
plt.xlabel('T, K', fontsize=12)
plt.ylabel(r'$\beta(P_i, T)_{ЗТВ}$', fontsize=12)
plt.grid(linestyle = '--')                          
plt.plot(T1, beta1, color='#1512a5'); plt.plot(T2, beta2, color='#19a327'); plt.plot(T3, beta3, color='#a3195c')
plt.plot(T4, beta4, color='#1512a5'); plt.plot(T5, beta5, color='#19a327'); plt.plot(T6, beta6, color='#a3195c')
plt.plot([-3000, 2000], [0,0], linewidth = 0.5, color='black') # горизонтальная ось
plt.plot([0,0], [-3000, 2000], linewidth = 0.5, color='black') # вертикальная ось
plt.plot([-267.67, -267.67], [1000,-1000], linestyle = '--', linewidth = 1, color='#1512a5') #1я верт.асимптота
plt.plot([-1189.22, -1189.22], [1000,-1000], linestyle = '--', linewidth = 1, color='#19a327') #2я верт.асимптота
plt.plot([-2341.17, -2341.17], [1000,-1000], linestyle = '--', linewidth = 1, color='#a3195c') #3я верт.асимптота
plt.text(500, 0.002, '1', fontsize=12) # кривая 1
plt.text(-550, 0.002, '2', fontsize=12) # кривая 2
plt.text(-1720, 0.002, '3', fontsize=12) # кривая 3
plt.savefig('Fig6.png', dpi=400, bbox_inches='tight')

# %%
# β(P,T)_зтп при разных P
# Рис.7

a0=0.00477762; a1=0.02952904; a2=0.00012817
b0=1; b1=0.0059004; b2=-0.00097392

T1 = np.linspace(-1000, 1031, num=1000); T2 = np.linspace(-1000, 1056, num=1000); T3 = np.linspace(-1000, 1086, num=1000)
T4 = np.linspace(1033, 2000, num=1000); T5 = np.linspace(1058, 2000, num=1000); T6 = np.linspace(1088, 2000, num=1000)
beta1 = 0.00097392/(1+0.0059004*1-0.00097392*T1); beta4 = 0.00097392/(1+0.0059004*1-0.00097392*T4)
beta2 = 0.00097392/(1+0.0059004*5-0.00097392*T2); beta5 = 0.00097392/(1+0.0059004*5-0.00097392*T5)
beta3 = 0.00097392/(1+0.0059004*10-0.00097392*T3); beta6 = 0.00097392/(1+0.0059004*10-0.00097392*T6)
plt.gca().set(xlim=(-1000, 2000), ylim=(-0.01, 0.01))
plt.xlabel('T, K', fontsize=12)
plt.ylabel(r'$\beta(P_i, T)_{ЗТП}$', fontsize=12)
plt.grid(linestyle = '--')
plt.plot(T1, beta1, color='#1512a5'); plt.plot(T2, beta2, color='#19a327'); plt.plot(T3, beta3, color='#a3195c')
plt.plot(T4, beta4, color='#1512a5'); plt.plot(T5, beta5, color='#19a327'); plt.plot(T6, beta6, color='#a3195c')
plt.plot([-3000, 2000], [0,0], linewidth = 0.5, color='black') # горизонтальная ось
plt.plot([0,0], [-3000, 2000], linewidth = 0.5, color='black') # вертикальная ось
plt.plot([1032.84, 1032.84], [1000,-1000], linestyle = '--', linewidth = 1, color='#1512a5') #1я верт.асимптота
plt.plot([1057.07, 1057.07], [1000,-1000], linestyle = '--', linewidth = 1, color='#19a327') #2я верт.асимптота
plt.plot([1087.36, 1087.36], [1000,-1000], linestyle = '--', linewidth = 1, color='#a3195c') #3я верт.асимптота

plt.text(1310, -0.0025, '1', fontsize=10) # кривая 1
plt.annotate('2', xy=(1290, -0.004), xytext=(1480, -0.005),
            arrowprops=dict(arrowstyle = "->", connectionstyle = "arc3")) # аннотация ко 2й кривой
plt.text(1600, -0.0029, '3', fontsize=10) # кривая 3
plt.savefig('Fig7.png', dpi=400, bbox_inches='tight')
